# %% [markdown]
# ### NAME: BERLINDA ACHEAMPONG
# ### STUDENT ID: 10986852
# ### CLASS: BIOMEDICAL ENGINEERING

# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\BLESSEDBRAIN PC WORK\\Desktop\\PIP LIST'

# %%
os.chdir('C:\\Users\\BLESSEDBRAIN PC WORK\\Desktop\\PIP LIST')

# %%
df = pd.read_csv('data.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0   1            7.4              0.70         0.00             1.9
# 1   2            7.8              0.88         0.00             2.6
# 2   3            7.8              0.76         0.04             2.3
# 3   4           11.2              0.28         0.56             1.9
# 4   5            7.4              0.70         0.00             1.9
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970   NaN
# 3      0.075                 17.0                  60.0   0.9980  3.16
# 4      0.076                 11.0                  34.0   0.9978  3.51
#
#    sulphates  alcohol  quality
# 0       0.56      9.4      5.0
# 1       0.68      9.8      5.0
# 2       0.65      9.8      5.0
# ...

# %%
df.isna()
# Out:
#          ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     False          False             False        False           False
# 1     False          False             False        False           False
# 2     False          False             False        False           False
# 3     False          False             False        False           False
# 4     False          False             False        False           False
# ...     ...            ...               ...          ...             ...
# 1596  False          False             False        False           False
# 1597  False          False             False        False           False
# 1598  False          False             False        False           False
# 1599  False          False             False        False           False
# 1600  False          False             False        False           False
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density     pH  \
# ...

# %% [markdown]
# ### This shows the places with the null values are indicated with 'true' and the the places values are shown with false

# %%
df.dropna()
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# 5        6            7.4             0.660         0.00             1.8
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %% [markdown]
# ### The dataset above had null values but was remove by running the df.dropna() code. The df.dropna() was used because the original dataset had null values and if those null values were not removed when  we are selecting a data and that data contains null value/s it will give inaccurate results.

# %%
df.drop_duplicates()
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1600 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1600 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1598 non-null   float64
#  6   free sulfur dioxide   1600 non-null   float64
#  7   total sulfur dioxide  1600 non-null   float64
#  8   density               1600 non-null   float64
#  9   pH                    1600 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1600 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB

# %%
df.describe()
# Out:
#                 ID  fixed acidity  volatile acidity  citric acid  \
# count  1601.000000    1600.000000       1601.000000  1600.000000
# mean    801.000000       8.319875          0.527742     0.271175
# std     462.313206       1.740039          0.178981     0.194745
# min       1.000000       4.600000          0.120000     0.000000
# 25%     401.000000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1201.000000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual sugar    chlorides  free sulfur dioxide  total sulfur dioxide  \
# count     1601.000000  1598.000000          1600.000000           1600.000000
# mean         2.538445     0.087487            15.886875             46.520000
# std          1.409138     0.047076            10.458487             32.977723
# ...

# %% [markdown]
# ### The dataset above gives the statistical inference of the entire dataset and this helps to predict the uncertainty of the dataset variations,also helps us to access the relationship between independent and dependent values of the dataset and this also helps us to accurately and effectively examine the dataset.

# %%
plt.figure()

# %%
sns.heatmap(df.corr(), annot=True, linewidth=0.5)
# Out:
# <Axes: >

# %% [markdown]
# ### The above heatmap gives a colourful  2D  visual display of how all the variables of the dataset are correlated in the form of colours instead of numbers. The colour changes describe the relationships amongst all the variables of the datase according to the intensity of the colour in a particular block. It highlights higher values than lighter values.

# %%
df.quality.mean()
# Out:
# 5.63625

# %%
df_summary = df.describe()

# %%
sns.set(style='darkgrid')

# %%
df.quality
# Out:
# 0       5.0
# 1       5.0
# 2       5.0
# 3       6.0
# 4       5.0
#        ...
# 1596    6.0
# 1597    6.0
# 1598    5.0
# 1599    6.0
# 1600    6.0
# Name: quality, Length: 1601, dtype: float64

# %%
plt.figure(figsize=(20,10))

# %%
ax = sns.countplot(x='quality',data=df)

# %%
x = df.quality < df.quality.mean()

# %%
x.value_counts()
# Out:
# False    857
# True     744
# Name: quality, dtype: int64

# %%
mycolors = ["black", "hotpink"]

# %%
plt.pie(x.value_counts(), labels=x.value_counts(), colors=mycolors, autopct='%1.1f%%', shadow=True, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x22372b5b7d0>,
# ...
#  [Text(-0.6094936507612937, -0.9157060061404372, '857'),
#   Text(0.6094937364958748, 0.9157059490755192, '744')],
#  [Text(-0.3324510822334329, -0.4994760033493293, '53.5%'),
#   Text(0.3324511289977498, 0.4994759722230104, '46.5%')])

# %%
plt.show()

# %%
df.pH
# Out:
# 0       3.51
# 1       3.20
# 2        NaN
# 3       3.16
# 4       3.51
#         ...
# 1596    3.52
# 1597    3.42
# 1598    3.57
# 1599    3.39
# 1600    3.30
# Name: pH, Length: 1601, dtype: float64

# %%
ax = sns.histplot(df, x='pH', bins=30, stat='probability')

# %%
ax.set(ylabel="$p(x)$")
# Out:
# [Text(25.078125, 0.5, '$p(x)$')]

# %%
df.pH.mean()
# Out:
# 3.3111062500000004

# %%
e = df.pH < df.pH.mean()

# %%
e.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       False
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 1596    False
# 1597    False
# 1598    False
# 1599    False
# 1600     True
# Name: pH, Length: 1601, dtype: bool>

# %%
mycolors = ["green", "blue"]

# %%
plt.pie(e.value_counts(), labels=e.value_counts(), colors=mycolors, autopct='%1.1f%%', shadow=True, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x22372c08910>,
# ...
#  [Text(-0.6691856242420442, -0.8730352801048683, '823'),
#   Text(0.6691856242420443, 0.8730352801048682, '778')],
#  [Text(-0.36501034049566045, -0.47620106187538264, '51.4%'),
#   Text(0.3650103404956605, 0.4762010618753826, '48.6%')])

# %%
df['fixed acidity']
# Out:
# 0        7.4
# 1        7.8
# 2        7.8
# 3       11.2
# 4        7.4
#         ...
# 1596     5.9
# 1597     6.3
# 1598     5.9
# 1599     6.0
# 1600     7.2
# Name: fixed acidity, Length: 1601, dtype: float64

# %%
ax = sns.histplot(df, x='fixed acidity', bins=40, stat='probability')

# %%
ax.set(ylabel="$p(x)$")
# Out:
# [Text(25.078125, 0.5, '$p(x)$')]

# %%
df['fixed acidity'].mean()
# Out:
# 8.319875000000001

# %%
b = df['fixed acidity'] < df['fixed acidity'].mean()

# %%
b.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        True
# 1        True
# 2        True
# 3       False
# 4        True
#         ...
# 1596     True
# 1597     True
# 1598     True
# 1599     True
# 1600     True
# Name: fixed acidity, Length: 1601, dtype: bool>

# %%
mycolors = ["green", "yellow"]

# %%
plt.pie(b.value_counts(), labels=b.value_counts(), colors=mycolors, autopct='%1.1f%%', shadow=True, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x223708ab610>,
# ...
#  [Text(-0.39318582513587996, -1.0273290159010489, '970'),
#   Text(0.39318582513588013, 1.0273290159010489, '631')],
#  [Text(-0.2144649955286618, -0.560361281400572, '60.6%'),
#   Text(0.21446499552866186, 0.560361281400572, '39.4%')])

# %%
df['volatile acidity']
# Out:
# 0       0.700
# 1       0.880
# 2       0.760
# 3       0.280
# 4       0.700
#         ...
# 1596    0.550
# 1597    0.510
# 1598    0.645
# 1599    0.310
# 1600    0.390
# Name: volatile acidity, Length: 1601, dtype: float64

# %%
ax = sns.histplot(df, x='volatile acidity', bins=20, stat='probability')

# %%
ax.set(ylabel="$p(x)$")
# Out:
# [Text(25.078125, 0.5, '$p(x)$')]

# %%
df['volatile acidity'].mean()
# Out:
# 0.5277420362273579

# %%
v = df['volatile acidity'] < df['volatile acidity'].mean()

# %%
v.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 1596    False
# 1597     True
# 1598    False
# 1599     True
# 1600     True
# Name: volatile acidity, Length: 1601, dtype: bool>

# %%
mycolors = ["black", "purple"]

# %%
plt.pie(v.value_counts(), labels=v.value_counts(), colors=mycolors, autopct='%1.1f%%', shadow=True, startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x223739acc50>,
# ...
#  [Text(-1.0994234860043215, -0.03560896547368202, '817'),
#   Text(1.0994234860043215, 0.03560896547368237, '784')],
#  [Text(-0.5996855378205389, -0.019423072076553825, '51.0%'),
#   Text(0.5996855378205389, 0.019423072076554016, '49.0%')])

# %%
df['citric acid']
# Out:
# 0       0.00
# 1       0.00
# 2       0.04
# 3       0.56
# 4       0.00
#         ...
# 1596    0.10
# 1597    0.13
# 1598    0.12
# 1599    0.47
# 1600    0.44
# Name: citric acid, Length: 1601, dtype: float64

# %%
ax = sns.histplot(df, x='citric acid', bins=10, stat='probability')

# %%
ax.set(ylabel="$p(x)$")
# Out:
# [Text(25.078125, 0.5, '$p(x)$')]

# %%
df['citric acid'].mean()
# Out:
# 0.271175

# %%
q = df['citric acid'] < df['citric acid'].mean()

# %%
q.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        True
# 1        True
# 2        True
# 3       False
# 4        True
#         ...
# 1596     True
# 1597     True
# 1598     True
# 1599    False
# 1600    False
# Name: citric acid, Length: 1601, dtype: bool>

# %%
mycolors = ["black", "orange"]

# %%
plt.pie(q.value_counts(), labels=q.value_counts(), colors=mycolors, autopct='%1.1f%%', shadow=True, startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x22374ae8d90>,
# ...
#  [Text(-1.0943879174833389, -0.11097335746241452, '852'),
#   Text(1.0943879278734097, 0.11097325499842227, '749')],
#  [Text(-0.5969388640818212, -0.060530922252226095, '53.2%'),
#   Text(0.5969388697491325, 0.06053086636277578, '46.8%')])

# %%
df['residual sugar']
# Out:
# 0       1.9
# 1       2.6
# 2       2.3
# 3       1.9
# 4       1.9
#        ...
# 1596    2.2
# 1597    2.3
# 1598    2.0
# 1599    3.6
# 1600    2.6
# Name: residual sugar, Length: 1601, dtype: float64

# %%
ax = sns.histplot(df, x='residual sugar', bins=5, stat='probability')

# %%
ax.set(ylabel="$p(x)$")
# Out:
# [Text(25.078125, 0.5, '$p(x)$')]

# %%
df['residual sugar'].mean()
# Out:
# 2.5384447220487196

# %%
g = df['residual sugar'] < df['residual sugar'].mean()

# %%
g.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        True
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 1596     True
# 1597     True
# 1598     True
# 1599    False
# 1600    False
# Name: residual sugar, Length: 1601, dtype: bool>

# %%
mycolors = ["black", "indigo"]

# %%
plt.pie(g.value_counts(), labels=g.value_counts(), colors=mycolors, autopct='%1.1f%%', shadow=True, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x22374b23690>,
# ...
#  [Text(0.018825915341529484, -1.0998388904342098, '1165'),
#   Text(-0.01882591534152935, 1.0998388904342098, '436')],
#  [Text(0.010268681095379716, -0.5999121220550235, '72.8%'),
#   Text(-0.010268681095379643, 0.5999121220550235, '27.2%')])

# %%
df['chlorides']
# Out:
# 0       0.076
# 1       0.098
# 2       0.092
# 3       0.075
# 4       0.076
#         ...
# 1596    0.062
# 1597    0.076
# 1598    0.075
# 1599    0.067
# 1600    0.066
# Name: chlorides, Length: 1601, dtype: float64

# %%
ax = sns.histplot(df, x='chlorides', bins=10, stat='probability')

# %%
ax = sns.histplot(df, x='chlorides', bins=10, stat='probability')

# %%
df['chlorides'].mean()
# Out:
# 0.0874874843554443

# %%
k = df['chlorides'] < df['chlorides'].mean()

# %%
k.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        True
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 1596     True
# 1597     True
# 1598     True
# 1599     True
# 1600     True
# Name: chlorides, Length: 1601, dtype: bool>

# %%
mycolors = ["black", "brown"]

# %%
plt.pie(k.value_counts(), labels=k.value_counts(), colors=mycolors, autopct='%1.1f%%', shadow=True, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x22374c670d0>,
# ...
#  [Text(-0.07177898822957451, -1.097655582069685, '1123'),
#   Text(0.0717790909995068, 1.097655575349246, '478')],
#  [Text(-0.039152175397949726, -0.5987212265834645, '70.1%'),
#   Text(0.03915223145427643, 0.5987212229177705, '29.9%')])

# %%
df['free sulfur dioxide']
# Out:
# 0       11.0
# 1       25.0
# 2       15.0
# 3       17.0
# 4       11.0
#         ...
# 1596    39.0
# 1597    29.0
# 1598    32.0
# 1599    18.0
# 1600    22.0
# Name: free sulfur dioxide, Length: 1601, dtype: float64

# %%
ax = sns.histplot(df, x='free sulfur dioxide', bins=10, stat='probability')

# %%
ax.set(ylabel="$p(x)$")
# Out:
# [Text(25.078125, 0.5, '$p(x)$')]

# %%
df['free sulfur dioxide'].mean()
# Out:
# 15.886875

# %%
r = df['free sulfur dioxide'] < df['free sulfur dioxide'].mean()

# %%
r.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        True
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 1596    False
# 1597    False
# 1598    False
# 1599    False
# 1600    False
# Name: free sulfur dioxide, Length: 1601, dtype: bool>

# %%
mycolors = ["yellow", "red"]

# %%
plt.pie(r.value_counts(), labels=r.value_counts(), colors=mycolors, autopct='%1.1f%%', shadow=True, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x22374d231d0>,
# ...
#  [Text(-0.4861277060351257, -0.9867521742692168, '923'),
#   Text(0.4861277984215297, 0.9867521287546518, '678')],
#  [Text(-0.26516056692825035, -0.5382284586923, '57.7%'),
#   Text(0.26516061732083435, 0.5382284338661736, '42.3%')])

# %%
df['total sulfur dioxide']
# Out:
# 0       34.0
# 1       67.0
# 2       54.0
# 3       60.0
# 4       34.0
#         ...
# 1596    51.0
# 1597    40.0
# 1598    44.0
# 1599    42.0
# 1600    48.0
# Name: total sulfur dioxide, Length: 1601, dtype: float64

# %%
ax = sns.histplot(df, x='total sulfur dioxide', bins=10, stat='probability')

# %%
ax.set(ylabel="$p(x)$")
# Out:
# [Text(25.078125, 0.5, '$p(x)$')]

# %%
df['total sulfur dioxide'].mean()
# Out:
# 46.52

# %%
t = df['total sulfur dioxide'] < df['total sulfur dioxide'].mean()

# %%
t.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        True
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1596    False
# 1597     True
# 1598     True
# 1599     True
# 1600    False
# Name: total sulfur dioxide, Length: 1601, dtype: bool>

# %%
mycolors = ["yellow", "blue"]

# %%
plt.pie(t.value_counts(), labels=t.value_counts(), colors=mycolors, autopct='%1.1f%%', shadow=True, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x22374e100d0>,
# ...
#  [Text(-0.38106352916024167, -1.0318869059853129, '976'),
#   Text(0.3810636257724647, 1.0318868703075659, '625')],
#  [Text(-0.20785283408740451, -0.562847403264716, '61.0%'),
#   Text(0.20785288678498073, 0.5628473838041267, '39.0%')])

# %%
df.density
# Out:
# 0       0.99780
# 1       0.99680
# 2       0.99700
# 3       0.99800
# 4       0.99780
#          ...
# 1596    0.99512
# 1597    0.99574
# 1598    0.99547
# 1599    0.99549
# 1600    0.99494
# Name: density, Length: 1601, dtype: float64

# %%
ax = sns.histplot(df, x='total sulfur dioxide', bins=40, stat='probability')

# %%
ax.set(ylabel="$p(x)$")
# Out:
# [Text(25.078125, 0.5, '$p(x)$')]

# %%
df.density.mean()
# Out:
# 0.9967456437500002

# %%
n = df.density < df.density.mean()

# %%
n.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1596     True
# 1597     True
# 1598     True
# 1599     True
# 1600     True
# Name: density, Length: 1601, dtype: bool>

# %%
mycolors = ["grey", "blue"]

# %%
plt.pie(n.value_counts(), labels=n.value_counts(), colors=mycolors, autopct='%1.1f%%', shadow=True, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x22374f28a90>,
# ...
#  [Text(-0.7045830265419, -0.8447264401621726, '802'),
#   Text(0.7045830265419001, 0.8447264401621725, '799')],
#  [Text(-0.38431801447739994, -0.4607598764520941, '50.1%'),
#   Text(0.38431801447740005, 0.46075987645209404, '49.9%')])

# %%
df.sulphates
# Out:
# 0       0.56
# 1       0.68
# 2       0.65
# 3       0.58
# 4       0.56
#         ...
# 1596    0.76
# 1597    0.75
# 1598    0.71
# 1599    0.66
# 1600    0.84
# Name: sulphates, Length: 1601, dtype: float64

# %%
ax = sns.histplot(df, x='sulphates', bins=40, stat='probability')

# %%
ax.set(ylabel="$p(x)$")
# Out:
# [Text(25.078125, 0.5, '$p(x)$')]

# %%
df.sulphates.mean()
# Out:
# 0.6582198625858838

# %%
h = df.sulphates < df.sulphates.mean()

# %%
h.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        True
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 1596    False
# 1597    False
# 1598    False
# 1599    False
# 1600    False
# Name: sulphates, Length: 1601, dtype: bool>

# %%
mycolors = ["violet", "blue"]

# %%
plt.pie(h.value_counts(), labels=h.value_counts(), colors=mycolors, autopct='%1.1f%%', shadow=True, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x223750270d0>,
# ...
#  [Text(-0.4032462083518961, -1.023421953765806, '965'),
#   Text(0.40324620835189623, 1.0234219537658058, '636')],
#  [Text(-0.21995247728285242, -0.5582301565995305, '60.3%'),
#   Text(0.21995247728285247, 0.5582301565995303, '39.7%')])

# %%
df.alcohol
# Out:
# 0        9.4
# 1        9.8
# 2        9.8
# 3        9.8
# 4        9.4
#         ...
# 1596    11.2
# 1597    11.0
# 1598    10.2
# 1599    11.0
# 1600    11.5
# Name: alcohol, Length: 1601, dtype: float64

# %%
ax = sns.histplot(df, x='alcohol', bins=40, stat='probability')

# %%
ax.set(ylabel="$p(x)$")
# Out:
# [Text(25.078125, 0.5, '$p(x)$')]

# %%
df.alcohol.mean()
# Out:
# 10.42320424734541

# %%
z = df.alcohol < df.alcohol.mean()

# %%
z.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1596    False
# 1597    False
# 1598     True
# 1599    False
# 1600    False
# Name: alcohol, Length: 1601, dtype: bool>

# %%
mycolors = ["violet", "green"]

# %%
plt.pie(z.value_counts(), labels=z.value_counts(), colors=mycolors, autopct='%1.1f%%', shadow=True, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x2237616acd0>,
# ...
#  [Text(-0.4977113358560319, -0.9809604610586526, '917'),
#   Text(0.497711335856032, 0.9809604610586526, '684')],
#  [Text(-0.27147891046692646, -0.5350693423956286, '57.3%'),
#   Text(0.2714789104669265, 0.5350693423956286, '42.7%')])

# %%
df.corr()
# Out:
#                             ID  fixed acidity  volatile acidity  citric acid  \
# ID                    1.000000      -0.268147         -0.009544    -0.153429
# fixed acidity        -0.268147       1.000000         -0.255570     0.671061
# volatile acidity     -0.009544      -0.255570          1.000000    -0.552917
# citric acid          -0.153429       0.671061         -0.552917     1.000000
# residual sugar       -0.031589       0.114601          0.001877     0.143518
# chlorides            -0.119363       0.093544          0.060826     0.204054
# free sulfur dioxide   0.091197      -0.153049         -0.010592    -0.061269
# total sulfur dioxide -0.113913      -0.113356          0.076249     0.036030
# density              -0.368825       0.667912          0.022771     0.364309
# pH                    0.135208      -0.682644          0.235306    -0.543019
# sulphates            -0.124243       0.182303         -0.261364     0.312895
# ...

# %% [markdown]
# ### The  above table shows how the columns  are correlated amongst each other in the form of pair-wise numbers and there is a weak negative correlation amongst all the columns. Also the values at the diagonal can be seen to be 1s and this indicates that each column is perfectly correlated with each other.

# %% [markdown]
# ### To conclude the dataset that was given had dependent and independent variables . The dependent variable is the 'QUALITY and the independent variables are the 'FIXED ACIDITY', 'VOLATILE ACIDITY', 'CITRIC ACID', 'RESIDUAL SUGAR', 'CHLORIDES', 'FREE SULFUR DIOXIDE', 'TOTAL SULFUR DIOXIDE', 'DENSITY', 'PH', 'SULPHATES' and 'ALCOHOL'. This means the number of  QUALITY RED WINES the Beverage Manufacturing Company is determined by the composition of the fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, ph, sulphates,density, and alcohol.
